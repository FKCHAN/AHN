# %% [markdown]
# Adapted from https://www.kaggle.com/code/taylorsamarel/change-python-version-on-kaggle-taylor-amarel

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rec05-multi/overall.yaml
# /kaggle/input/rec05-multi/torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl
# /kaggle/input/rec05-multi/metrics.py
# /kaggle/input/rec05-multi/torch_sparse-0.6.15-cp37-cp37m-linux_x86_64.whl
# /kaggle/input/rec05-multi/torch_cluster-1.6.0-cp37-cp37m-linux_x86_64.whl
# /kaggle/input/rec05-multi/configurator.py
# /kaggle/input/rec05-multi/smore.py
# /kaggle/input/rec05-multi/MMRec-master/LICENSE
# /kaggle/input/rec05-multi/MMRec-master/.gitignore
# /kaggle/input/rec05-multi/MMRec-master/README.md
# /kaggle/input/rec05-multi/MMRec-master/requirements.txt
# /kaggle/input/rec05-multi/MMRec-master/reports/MMRec-reports.pdf
# /kaggle/input/rec05-multi/MMRec-master/.idea/.gitignore
# /kaggle/input/rec05-multi/MMRec-master/.idea/modules.xml
# /kaggle/input/rec05-multi/MMRec-master/.idea/workspace.xml
# /kaggle/input/rec05-multi/MMRec-master/.idea/MMRec.iml
# /kaggle/input/rec05-multi/MMRec-master/.idea/misc.xml
# ...

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
! git init
! git clone https://github.com/enoche/MMRec.git
# Out:
# Initialized empty Git repository in /kaggle/working/.git/
# Cloning into 'MMRec'...
# remote: Enumerating objects: 398, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 398 (delta 92), reused 73 (delta 68), pack-reused 277 (from 2)
# Receiving objects: 100% (398/398), 634.30 KiB | 12.44 MiB/s, done.
# Resolving deltas: 100% (180/180), done.

# %%
# !mkdir /kaggle/working/MMRec/data/baby/
# !mkdir /kaggle/working/MMRec/src/dataset/
# !mkdir /kaggle/working/MMRec/src/model/

# %%
from shutil import copyfile
 
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/data/baby/baby.inter", dst = "/kaggle/working/MMRec/data/baby/baby.inter")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/data/baby/image_feat.npy", dst = "/kaggle/working/MMRec/data/baby/image_feat.npy")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/data/baby/text_feat.npy", dst = "/kaggle/working/MMRec/data/baby/text_feat.npy")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/data/baby/user_graph_dict.npy", dst = "/kaggle/working/MMRec/data/baby/user_graph_dict.npy")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/data/baby/i_id_mapping.csv", dst = "/kaggle/working/MMRec/data/baby/i_id_mapping.csv")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/data/baby/u_id_mapping.csv", dst = "/kaggle/working/MMRec/data/baby/u_id_mapping.csv")
copyfile(src = "/kaggle/input/rec05-multi/overall.yaml", dst = "/kaggle/working/MMRec/src/configs/overall.yaml")
# copyfile(src = "/kaggle/input/rec05-multi/SMORE-main/src/models/smore.py", dst = "/kaggle/working/SMORE/src/models/smore.py")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/requirements.txt", dst = "/kaggle/working/MMRec/requirements.txt")
copyfile(src = "/kaggle/input/rec05-multi/configurator.py", dst = "/kaggle/working/MMRec/src/utils/configurator.py")
copyfile(src = "/kaggle/input/rec05-multi/torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl", dst = "/kaggle/working/MMRec/torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl")
# copyfile(src = "/kaggle/input/rec05-multi/metrics.py", dst = "/kaggle/working/MMRec/src/utils/misc.py")
# copyfile(src = "/kaggle/input/22222222/load_data.py", dst = "/kaggle/working/ReviewGraph/load_data.py")
copyfile(src = "/kaggle/input/rec05-multi/overall.yaml", dst = "/kaggle/working/MMRec/src/overall.yaml")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/src/configs/dataset/baby.yaml", dst = "/kaggle/working/MMRec/src/dataset/baby.yaml")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/src/configs/model/SMORE.yaml", dst = "/kaggle/working/MMRec/src/model/SMORE.yaml")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/src/configs/mg.yaml", dst = "/kaggle/working/MMRec/src/mg.yaml")
copyfile(src = "/kaggle/input/rec05-multi/smore.py", dst = "/kaggle/working/MMRec/src/models/smore.py")
# Out:
# '/kaggle/working/MMRec/src/models/smore.py'

# %%
from shutil import copyfile
 
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/src/configs/model/FREEDOM.yaml", dst = "/kaggle/working/MMRec/src/model/FREEDOM.yaml")
copyfile(src = "/kaggle/input/rec05-multi/MMRec-master/src/configs/model/LGMRec.yaml", dst = "/kaggle/working/MMRec/src/model/LGMRec.yaml")
# Out:
# '/kaggle/working/MMRec/src/model/LGMRec.yaml'

# %%
import torch
 
# 获取CUDA版本
cuda_version = torch.version.cuda
 
print(f"CUDA version: {cuda_version}")
import sys
print(sys.version)
# Out:
# CUDA version: 11.0
# 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/11.7.0/local_installers/cuda_11.7.0_515.43.04_linux.run

# %%
# !sudo sh cuda_11.7.0_515.43.04_linux.run

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
pip install lmdb

# %%
pip install -r /kaggle/working/MMRec/requirements.txt

# %%
# !pip install torch==2.3.1+cu121 torchvision==0.18.1+cu121 --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 --extra-index-url https://download.pytorch.org/whl/cu110

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/11.3.0/local_installers/cuda_11.3.0_465.19.01_linux.run

# %%
# !chmod 777 ./cuda_11.3.0_465.19.01_linux.run
# !./cuda_11.3.0_465.19.01_linux.run  --silent    --toolkit  --toolkitpath=~/cuda_11.3

# %%
ll ~

# %%
ll /usr/local

# %%
import torch
print(torch.__version__)
exit()

# %%
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# pip install torch-scatter==2.0.7 -f https://data.pyg.org/whl/torch-1.7.1%2Bcu110.html

# %%
pip install torch-scatter==2.1.0 -f https://data.pyg.org/whl/torch-1.12.1%2Bcu113.html

# %%
# !nvidia-smi

# %%
# !nvcc --version

# %%
import numpy as np
print(np.__version__)

# %%
pip install numpy==1.21.5

# %%
# !python /kaggle/working/MMRec/src/main.py -m SMORE
